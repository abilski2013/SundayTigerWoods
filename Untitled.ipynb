# %%
import pandas as pd
import geopandas as gpd
import fiona
import pymongo

# %%
water_df = pd.read_csv("static/data/countypop_2017.csv")
water_df = gpd.GeoDataFrame(water_df)
water_df = water_df.rename(columns={"County": "name"})

# %%
mn_df = pd.read_csv("static/data/water.csv")
mn_df = gpd.GeoDataFrame(mn_df)
pop= mn_df.loc[mn_df['year']==2017]
population = pop.groupby(['countyServed','analyteCode'], as_index = False).sum()
population
# Out:
#         countyServed analyteCode     year  populationServed      fips
# 0             Aitkin     Arsenic  12102.0            3430.0  162006.0
# 1             Aitkin        HAA5   8068.0            3360.0  108004.0
# 2             Aitkin     Nitrate  12102.0            3430.0  162006.0
# 3             Aitkin         PCE  12102.0            3430.0  162006.0
# 4             Aitkin      Radium  12102.0            3430.0  162006.0
# ..               ...         ...      ...               ...       ...
# 642  Yellow Medicine         PCE  12102.0            6420.0  163038.0
# 643  Yellow Medicine      Radium  18153.0            6774.0  244557.0
# 644  Yellow Medicine         TCE  12102.0            6420.0  163038.0
# 645  Yellow Medicine        TTHM  18153.0            6774.0  244557.0
# 646  Yellow Medicine     Uranium   2017.0             269.0   27173.0
#
# [647 rows x 5 columns]

# %%
water_df = gpd.GeoDataFrame(water_df)
water_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6b44f1794cde> in <module>
# ----> 1 water_df = gpd.GeoDataFrame(water_df)
#       2 water_df.head()
#
# NameError: name 'water_df' is not defined

# %%
boundaries_df = gpd.GeoDataFrame(boundaries)
columns = ['intptlat', 'countyfp_nozero', 'lsad', 'intptlon', 'funcstat', 'stusab',
'countyfp','geoid', 'countyns', 'mtfcc', 'classfp', 'statefp', 'aland', 'csafp','cbsafp','awater','namelsad']
boundaries_df.drop(columns, inplace=True, axis=1)
boundaries_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-7dddaef3681d> in <module>
# ----> 1 boundaries_df = gpd.GeoDataFrame(boundaries)
#       2 columns = ['intptlat', 'countyfp_nozero', 'lsad', 'intptlon', 'funcstat', 'stusab',
#       3 'countyfp','geoid', 'countyns', 'mtfcc', 'classfp', 'statefp', 'aland', 'csafp','cbsafp','awater','namelsad']
#       4 boundaries_df.drop(columns, inplace=True, axis=1)
#       5 boundaries_df
#
# NameError: name 'boundaries' is not defined

# %%
population_df = population.rename(columns={"countyServed": "name"})
population_df
# Out:
#                 name analyteCode     year  populationServed      fips
# 0             Aitkin     Arsenic  12102.0            3430.0  162006.0
# 1             Aitkin        HAA5   8068.0            3360.0  108004.0
# 2             Aitkin     Nitrate  12102.0            3430.0  162006.0
# 3             Aitkin         PCE  12102.0            3430.0  162006.0
# 4             Aitkin      Radium  12102.0            3430.0  162006.0
# ..               ...         ...      ...               ...       ...
# 642  Yellow Medicine         PCE  12102.0            6420.0  163038.0
# 643  Yellow Medicine      Radium  18153.0            6774.0  244557.0
# 644  Yellow Medicine         TCE  12102.0            6420.0  163038.0
# 645  Yellow Medicine        TTHM  18153.0            6774.0  244557.0
# 646  Yellow Medicine     Uranium   2017.0             269.0   27173.0
#
# [647 rows x 5 columns]

# %%
mn_data = gpd.read_file("static/data/MN-county-boundaries.geojson")
mn_data
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to read GeoJSON data
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-73-1217887aa6ce> in <module>
# ----> 1 mn_data = gpd.read_file("static/data/MN-county-boundaries.geojson")
#       2 mn_data
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
#      78             # In a future Fiona release the crs attribute of features will
#
# ...

# %%
pop_data = water_df.merge(mn_data,on = 'name')
pop_data.drop('fips', inplace=True, axis=1)
pop_data
# Out:
#      Unnamed: 0             name  Year  Population analyteCode  year  \
# 0             0           Aitkin  2017         628     Arsenic  2017
# 1             0           Aitkin  2017         628        HAA5  2017
# 2             0           Aitkin  2017         628     Nitrate  2017
# 3             0           Aitkin  2017         628         PCE  2017
# 4             0           Aitkin  2017         628      Radium  2017
# ..          ...              ...   ...         ...         ...   ...
# 642          86  Yellow Medicine  2017         809         PCE  2017
# 643          86  Yellow Medicine  2017         809      Radium  2017
# 644          86  Yellow Medicine  2017         809         TCE  2017
# 645          86  Yellow Medicine  2017         809        TTHM  2017
# 646          86  Yellow Medicine  2017         809     Uranium  2017
#
#      mean_value  max_value                                           geometry
# ...

# %%
mn_df= water_df.groupby(['name','analyteCode','year'],as_index= False)
mn_df =mn_df.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-84a0d35c8ce5> in <module>
# ----> 1 mn_df= water_df.groupby(['name','analyteCode','year'],as_index= False)
#       2 mn_df =mn_df.mean()
#
# NameError: name 'water_df' is not defined

# %%
mn_data
# Out:
#         name analyteCode  year  mean_value  max_value   fips  \
# 0     Aitkin     Arsenic  2017         3.4        3.5  27001
# 1     Aitkin        HAA5  2017         2.3        2.3  27001
# 2     Aitkin     Nitrate  2017         0.0        0.0  27001
# 3     Aitkin         PCE  2017         0.4        0.4  27001
# 4     Aitkin      Radium  2017         0.7        0.7  27001
# ..       ...         ...   ...         ...        ...    ...
# 295  Lincoln     Arsenic  2017         1.0        1.9  27081
# 296  Lincoln        HAA5  2017         7.1       11.5  27081
# 297  Lincoln     Nitrate  2017         4.8        5.8  27081
# 298  Lincoln         PCE  2017         0.5        0.5  27081
# 299  Lincoln      Radium  2017         0.5        0.5  27081
#
#                                               geometry
# 0    POLYGON ((-93.77799 46.59493, -93.77799 46.595...
# 1    POLYGON ((-93.77799 46.59493, -93.77799 46.595...
# 2    POLYGON ((-93.77799 46.59493, -93.77799 46.595...
# ...

# %%
mn_data.astype({'year': 'int', 'name': 'str', 'fips': 'int'}).dtypes
# Out:
# name            object
# analyteCode     object
# year             int64
# mean_value     float64
# max_value      float64
# fips             int64
# intptlat        object
# intptlon        object
# dtype: object

# %%
mn_df.to_csv('mn_water_data.csv')

# %%
clean_mn=mn_df.round()
clean_mn
# Out:
#                   name analyteCode  year  mean_value  max_value   fips
# 0               Aitkin     Arsenic  1998         3.0        3.0  27001
# 1               Aitkin     Arsenic  1999         3.0        3.0  27001
# 2               Aitkin     Arsenic  2001         3.0        3.0  27001
# 3               Aitkin     Arsenic  2002         3.0        3.0  27001
# 4               Aitkin     Arsenic  2003         3.0        3.0  27001
# ...                ...         ...   ...         ...        ...    ...
# 10507  Yellow Medicine     Uranium  2013        21.0       21.0  27173
# 10508  Yellow Medicine     Uranium  2014        21.0       21.0  27173
# 10509  Yellow Medicine     Uranium  2015        21.0       21.0  27173
# 10510  Yellow Medicine     Uranium  2016        21.0       21.0  27173
# 10511  Yellow Medicine     Uranium  2017        21.0       21.0  27173
#
# [10512 rows x 6 columns]

# %%
conn = 'mongodb://localhost:27017'

# %%
client = pymongo.MongoClient(conn)

# %%
db = client.water_db

# %%
db.water_db.drop()

# %%
mn_data.to_csv('mn_water_data-coord.csv', index=False)

# %%
mn_data_clean.to_file("mn_water_data-coord.json", driver='GeoJSON', index= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-995a72e887ae> in <module>
# ----> 1 mn_data_clean.to_file("mn_water_data-coord.json", driver='GeoJSON', index= False)
#
# NameError: name 'mn_data_clean' is not defined

# %%
pop_data.to_file("pop_data.geojson", driver = 'GeoJSON', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-605a3672721e> in <module>
# ----> 1 pop_data.to_file("pop_data.geojson", driver = 'GeoJSON', index = False)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     502         from geopandas.io.file import to_file
#     503
# --> 504         to_file(self, filename, driver, schema, **kwargs)
#     505
#     506     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/geopandas/io/file.py in to_file(df, filename, driver, schema, **kwargs)
#     128             filename, "w", driver=driver, crs=df.crs, schema=schema, **kwargs
#     129         ) as colxn:
# --> 130             colxn.writerecords(df.iterfeatures())
#     131
#     132
#
# ...
